# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 11.0 MB/s eta 0:00:00
# ...

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
model = YOLO("yolov8x.pt")
# Out:
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 241MB/s]

# %%
results = model("https://ultralytics.com/images/bus.jpg" , save=True)
# Out:
# ...
# 100%|██████████| 476k/476k [00:00<00:00, 11.5MB/s]
# image 1/1 /content/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 145.2ms
# Speed: 12.5ms preprocess, 145.2ms inference, 42.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict

# %%
model.train(data="/content/drive/MyDrive/Persian_License_Plate/data.yaml" , epochs=64)
# Out:
# Ultralytics YOLOv8.0.212 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
new_model = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
result1 = new_model("/content/drive/MyDrive/Persian_License_Plate/test/images/120__jpg.rf.d9febf2d41ec8817b1f241f3f0cd67ad.jpg" , save=True)
# Out:
# image 1/1 /content/drive/MyDrive/Persian_License_Plate/test/images/120__jpg.rf.d9febf2d41ec8817b1f241f3f0cd67ad.jpg: 640x640 3 License-Plates, 97.1ms
# Speed: 2.2ms preprocess, 97.1ms inference, 8.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
image= cv2.imread("/content/runs/detect/predict2/120__jpg.rf.d9febf2d41ec8817b1f241f3f0cd67ad.jpg")
image = cv2.cvtColor(image , cv2.COLOR_BGR2RGB)
plt.imshow(image)

# %%
result2 = new_model("/content/drive/MyDrive/Persian_License_Plate/test/images/IMG_20231106_1731391_jpg.rf.4ab2cdd905699da8e9a056ac33f3161f.jpg" , save=True)
# Out:
# image 1/1 /content/drive/MyDrive/Persian_License_Plate/test/images/IMG_20231106_1731391_jpg.rf.4ab2cdd905699da8e9a056ac33f3161f.jpg: 640x640 3 License-Plates, 95.9ms
# Speed: 2.1ms preprocess, 95.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
image2 = cv2.imread("/content/runs/detect/predict2/IMG_20231106_1731391_jpg.rf.4ab2cdd905699da8e9a056ac33f3161f.jpg")
image2 = cv2.cvtColor(image2 , cv2.COLOR_BGR2RGB)
plt.imshow(image2)
